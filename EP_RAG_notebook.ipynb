# %% [markdown]
# ## Retrieval Augmented Generation (RAG)
#
#
# *   [Google colab code](https://colab.research.google.com/drive/1sGueWwbTMm0BnMfX4FEfstYj4ujBLss8?usp=sharing)
# *   [CSV files used](https://drive.google.com/drive/folders/1gKQpVCNfNKJ_JTftAGthQlotuWlERjMr?usp=drive_link)
# *   [Embeddings](https://drive.google.com/file/d/1r6vD-9Sl3ONTSi75dP3Frrl_pui5dYtd/view?usp=drive_link)
# *   [Unstructured data (PDF files)](https://drive.google.com/drive/folders/1rzYfRD74WCPCp1NtSdJRgAqAOvmu2eV5?usp=drive_link)
